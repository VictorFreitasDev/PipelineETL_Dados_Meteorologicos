# %%
path = '../data/weather_data.json'
import pandas as pd
import json

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
with open(path) as f:
    data = json.load(f)

df = pd.json_normalize(data)
df.head()
# Out:
#                                                                      weather  \
# 0  [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}]
#
#        base  visibility          dt  timezone       id       name  cod  \
# 0  stations       10000  1788203702    -10800  3448439  São Paulo  200
#
#    coord.lon  coord.lat  main.temp  main.feels_like  main.temp_min  \
# 0   -46.6361   -23.5475       24.9             25.2          23.94
#
#    main.temp_max  main.pressure  main.humidity  main.sea_level  \
# 0           25.2           1008             67            1008
#
#    main.grnd_level  wind.speed  wind.deg  clouds.all  sys.type  sys.id  \
# 0              920        4.63        50           0         1    8394
#
#   sys.country  sys.sunrise  sys.sunset
# 0          BR   1788167916  1788209738

# %%
df.info
# Out:
# <bound method DataFrame.info of                                                                      weather  \
# 0  [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}]
#
#        base  visibility          dt  timezone       id       name  cod  \
# 0  stations       10000  1788203702    -10800  3448439  São Paulo  200
#
#    coord.lon  coord.lat  main.temp  main.feels_like  main.temp_min  \
# 0   -46.6361   -23.5475       24.9             25.2          23.94
#
#    main.temp_max  main.pressure  main.humidity  main.sea_level  \
# 0           25.2           1008             67            1008
#
#    main.grnd_level  wind.speed  wind.deg  clouds.all  sys.type  sys.id  \
# 0              920        4.63        50           0         1    8394
#
#   sys.country  sys.sunrise  sys.sunset
# 0          BR   1788167916  1788209738  >
